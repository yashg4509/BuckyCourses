# %%
# !pip install langchain
# !pip install chainlit
# !pip install streamlit streamlit_chat langchain openai faiss-cpu tiktoken
# Out:
# Requirement already satisfied: langchain in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (0.0.329)
# Requirement already satisfied: requests<3,>=2 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from langchain) (2.28.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from langchain) (0.5.8)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.52 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from langchain) (0.0.56)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from langchain) (3.8.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from langchain) (1.33)
# Requirement already satisfied: numpy<2,>=1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from langchain) (1.26.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from langchain) (8.2.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from langchain) (4.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from langchain) (2.0.23)
# Requirement already satisfied: PyYAML>=5.3 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from langchain) (6.0)
# Requirement already satisfied: pydantic<3,>=1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from langchain) (2.4.2)
# Requirement already satisfied: anyio<4.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from langchain) (3.7.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (21.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: exceptiongroup in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from anyio<4.0->langchain) (1.1.2)
# Requirement already satisfied: idna>=2.8 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from anyio<4.0->langchain) (3.3)
# Requirement already satisfied: sniffio>=1.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from anyio<4.0->langchain) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: pydantic-core==2.10.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (2.10.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (4.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2023.7.22)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (1.26.11)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain) (1.1.1)
# Requirement already satisfied: packaging>=17.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.7,>=0.5.7->langchain) (23.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from typing-inspect>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (0.4.3)
# Requirement already satisfied: chainlit in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (0.7.400)
# Requirement already satisfied: syncer<3.0.0,>=2.0.3 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (2.0.3)
# Requirement already satisfied: aiofiles<24.0.0,>=23.1.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (23.2.1)
# Requirement already satisfied: fastapi<0.101,>=0.100 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (0.100.1)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (8.1.7)
# Requirement already satisfied: pydantic<3,>=1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (2.4.2)
# Requirement already satisfied: lazify<0.5.0,>=0.4.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (0.4.0)
# Requirement already satisfied: fastapi-socketio<0.0.11,>=0.0.10 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (0.0.10)
# Requirement already satisfied: asyncer<0.0.3,>=0.0.2 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (0.0.2)
# Requirement already satisfied: dataclasses_json<0.6.0,>=0.5.7 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (0.5.8)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.4 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (3.8.4)
# Requirement already satisfied: python-graphql-client<0.5.0,>=0.4.3 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (0.4.3)
# Requirement already satisfied: python-multipart<0.0.7,>=0.0.6 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (0.0.6)
# Requirement already satisfied: prisma<0.11.0,>=0.10.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (0.10.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (1.2.0)
# Requirement already satisfied: uptrace<2.0.0,>=1.18.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (1.20.2)
# Requirement already satisfied: pyjwt<3.0.0,>=2.8.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (2.8.0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (1.0.0)
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (2.0.1)
# Requirement already satisfied: uvicorn<0.24.0,>=0.23.2 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (0.23.2)
# Requirement already satisfied: packaging<24.0,>=23.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (23.2)
# Requirement already satisfied: watchfiles<0.21.0,>=0.20.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (0.20.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.6 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from chainlit) (1.5.8)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.4->chainlit) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.4->chainlit) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.4->chainlit) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.4->chainlit) (4.0.2)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.4->chainlit) (2.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.4->chainlit) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.4->chainlit) (21.4.0)
# Requirement already satisfied: anyio<4.0.0,>=3.4.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from asyncer<0.0.3,>=0.0.2->chainlit) (3.7.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from dataclasses_json<0.6.0,>=0.5.7->chainlit) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from dataclasses_json<0.6.0,>=0.5.7->chainlit) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from dataclasses_json<0.6.0,>=0.5.7->chainlit) (1.5.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from fastapi<0.101,>=0.100->chainlit) (0.27.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from fastapi<0.101,>=0.100->chainlit) (4.8.0)
# Requirement already satisfied: python-socketio>=4.6.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from fastapi-socketio<0.0.11,>=0.0.10->chainlit) (5.10.0)
# Requirement already satisfied: nodeenv in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from prisma<0.11.0,>=0.10.0->chainlit) (1.8.0)
# Requirement already satisfied: jinja2>=2.11.2 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from prisma<0.11.0,>=0.10.0->chainlit) (3.1.2)
# Requirement already satisfied: httpx>=0.19.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from prisma<0.11.0,>=0.10.0->chainlit) (0.25.0)
# Requirement already satisfied: tomlkit in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from prisma<0.11.0,>=0.10.0->chainlit) (0.12.0)
# Requirement already satisfied: pydantic-core==2.10.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1->chainlit) (2.10.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1->chainlit) (0.6.0)
# Requirement already satisfied: requests~=2.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from python-graphql-client<0.5.0,>=0.4.3->chainlit) (2.28.1)
# Requirement already satisfied: websockets>=5.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from python-graphql-client<0.5.0,>=0.4.3->chainlit) (11.0.3)
# Requirement already satisfied: opentelemetry-api~=1.20 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from uptrace<2.0.0,>=1.18.0->chainlit) (1.20.0)
# Requirement already satisfied: opentelemetry-exporter-otlp~=1.20 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from uptrace<2.0.0,>=1.18.0->chainlit) (1.20.0)
# Requirement already satisfied: opentelemetry-sdk~=1.20 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from uptrace<2.0.0,>=1.18.0->chainlit) (1.20.0)
# Requirement already satisfied: opentelemetry-instrumentation~=0.41b0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from uptrace<2.0.0,>=1.18.0->chainlit) (0.41b0)
# Requirement already satisfied: h11>=0.8 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from uvicorn<0.24.0,>=0.23.2->chainlit) (0.14.0)
# Requirement already satisfied: exceptiongroup in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from anyio<4.0.0,>=3.4.0->asyncer<0.0.3,>=0.0.2->chainlit) (1.1.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from anyio<4.0.0,>=3.4.0->asyncer<0.0.3,>=0.0.2->chainlit) (1.2.0)
# Requirement already satisfied: idna>=2.8 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from anyio<4.0.0,>=3.4.0->asyncer<0.0.3,>=0.0.2->chainlit) (3.3)
# Requirement already satisfied: certifi in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.19.0->prisma<0.11.0,>=0.10.0->chainlit) (2023.7.22)
# Requirement already satisfied: httpcore<0.19.0,>=0.18.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.19.0->prisma<0.11.0,>=0.10.0->chainlit) (0.18.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from jinja2>=2.11.2->prisma<0.11.0,>=0.10.0->chainlit) (2.0.1)
# Requirement already satisfied: importlib-metadata<7.0,>=6.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-api~=1.20->uptrace<2.0.0,>=1.18.0->chainlit) (6.8.0)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-api~=1.20->uptrace<2.0.0,>=1.18.0->chainlit) (1.2.14)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.20.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-exporter-otlp~=1.20->uptrace<2.0.0,>=1.18.0->chainlit) (1.20.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.20.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-exporter-otlp~=1.20->uptrace<2.0.0,>=1.18.0->chainlit) (1.20.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.20.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.20.0->opentelemetry-exporter-otlp~=1.20->uptrace<2.0.0,>=1.18.0->chainlit) (1.20.0)
# Requirement already satisfied: opentelemetry-proto==1.20.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.20.0->opentelemetry-exporter-otlp~=1.20->uptrace<2.0.0,>=1.18.0->chainlit) (1.20.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.20.0->opentelemetry-exporter-otlp~=1.20->uptrace<2.0.0,>=1.18.0->chainlit) (1.51.1)
# Requirement already satisfied: backoff<3.0.0,>=1.10.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.20.0->opentelemetry-exporter-otlp~=1.20->uptrace<2.0.0,>=1.18.0->chainlit) (2.2.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.20.0->opentelemetry-exporter-otlp~=1.20->uptrace<2.0.0,>=1.18.0->chainlit) (1.61.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-proto==1.20.0->opentelemetry-exporter-otlp-proto-grpc==1.20.0->opentelemetry-exporter-otlp~=1.20->uptrace<2.0.0,>=1.18.0->chainlit) (4.24.3)
# Requirement already satisfied: setuptools>=16.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-instrumentation~=0.41b0->uptrace<2.0.0,>=1.18.0->chainlit) (63.4.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-instrumentation~=0.41b0->uptrace<2.0.0,>=1.18.0->chainlit) (1.12.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.41b0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-sdk~=1.20->uptrace<2.0.0,>=1.18.0->chainlit) (0.41b0)
# Requirement already satisfied: python-engineio>=4.8.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from python-socketio>=4.6.0->fastapi-socketio<0.0.11,>=0.0.10->chainlit) (4.8.0)
# Requirement already satisfied: bidict>=0.21.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from python-socketio>=4.6.0->fastapi-socketio<0.0.11,>=0.0.10->chainlit) (0.22.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from requests~=2.0->python-graphql-client<0.5.0,>=0.4.3->chainlit) (1.26.11)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from typing-inspect>=0.4.0->dataclasses_json<0.6.0,>=0.5.7->chainlit) (0.4.3)
# Requirement already satisfied: zipp>=0.5 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata<7.0,>=6.0->opentelemetry-api~=1.20->uptrace<2.0.0,>=1.18.0->chainlit) (3.8.0)
# Requirement already satisfied: simple-websocket>=0.10.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from python-engineio>=4.8.0->python-socketio>=4.6.0->fastapi-socketio<0.0.11,>=0.0.10->chainlit) (1.0.0)
# Requirement already satisfied: wsproto in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from simple-websocket>=0.10.0->python-engineio>=4.8.0->python-socketio>=4.6.0->fastapi-socketio<0.0.11,>=0.0.10->chainlit) (1.2.0)
# Requirement already satisfied: streamlit in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (1.27.1)
# Collecting streamlit_chat
#   Downloading streamlit_chat-0.1.1-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 13.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: langchain in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (0.0.329)
# Requirement already satisfied: openai in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (0.27.8)
# Collecting faiss-cpu
#   Using cached faiss_cpu-1.7.4-cp39-cp39-macosx_10_9_x86_64.whl (6.5 MB)
# Requirement already satisfied: tiktoken in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (0.5.1)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (13.6.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: typing-extensions<5,>=4.1.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (4.8.0)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (9.2.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: altair<6,>=4.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: pyarrow>=6.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (13.0.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (4.24.3)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (3.1.40)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: click<9,>=7.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: validators<1,>=0.2 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (0.22.0)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (6.8.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (1.26.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: packaging<24,>=16.8 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (23.2)
# Requirement already satisfied: requests<3,>=2.27 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (2.28.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (6.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (2.1.1)
# Requirement already satisfied: anyio<4.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from langchain) (3.7.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from langchain) (1.33)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from langchain) (2.0.23)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from langchain) (0.5.8)
# Requirement already satisfied: PyYAML>=5.3 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from langchain) (6.0)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from langchain) (4.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from langchain) (3.8.4)
# Requirement already satisfied: pydantic<3,>=1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from langchain) (2.4.2)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.52 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from langchain) (0.0.56)
# Requirement already satisfied: tqdm in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from openai) (4.64.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from tiktoken) (2022.7.9)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (21.4.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: jsonschema>=3.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (4.16.0)
# Requirement already satisfied: toolz in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (0.11.2)
# Requirement already satisfied: entrypoints in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from anyio<4.0->langchain) (1.2.0)
# Requirement already satisfied: exceptiongroup in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from anyio<4.0->langchain) (1.1.2)
# Requirement already satisfied: idna>=2.8 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from anyio<4.0->langchain) (3.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.8.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: tzdata>=2022.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from pandas<3,>=1.3.0->streamlit) (2022.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (2.10.1)
# Requirement already satisfied: six>=1.5 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (2023.7.22)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain) (1.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.0.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/yashgupta/opt/anaconda3/lib/python3.9/site-packages (from typing-inspect>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (0.4.3)
# Installing collected packages: faiss-cpu, streamlit_chat
# Successfully installed faiss-cpu-1.7.4 streamlit_chat-0.1.1

# %%
from langchain import PromptTemplate
from langchain.chains import LLMChain, SimpleSequentialChain
from langchain.chat_models import ChatOpenAI
import os

os.environ['OPENAI_API_KEY'] = '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'
apikey = os.getenv('OPENAI_API_KEY')

# %%
# agent.py
from langchain import OpenAI
from langchain.agents import create_pandas_dataframe_agent
import pandas as pd

# Setting up the api key
import environ

env = environ.Env()
environ.Env.read_env()

API_KEY = env("apikey")


def create_agent(filename: str):
    """
    Create an agent that can access and use a large language model (LLM).

    Args:
        filename: The path to the CSV file that contains the data.

    Returns:
        An agent that can access and use the LLM.
    """

    # Create an OpenAI object.
    llm = OpenAI(openai_api_key=API_KEY)

    # Read the CSV file into a Pandas DataFrame.
    df = pd.read_csv(filename)

    # Create a Pandas DataFrame agent.
    return create_pandas_dataframe_agent(llm, df, verbose=False)
